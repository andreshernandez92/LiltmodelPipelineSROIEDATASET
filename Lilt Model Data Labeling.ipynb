# %%
import os
import glob
import json
import random
from pathlib import Path
from difflib import SequenceMatcher
import cv2
import pandas as pd
import numpy as np
from PIL import Image
from tqdm import tqdm
from IPython.display import display
import matplotlib
from matplotlib import pyplot, patches
# !pip install tqdm --upgrade
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)

# %%
sroie_folder_path = Path('/content/drive/MyDrive/SROIE2019')
example_file = Path('X00016469670.txt')

# %%
def read_bbox_and_words(path: Path):
  bbox_and_words_list = []

  with open(path, 'r', errors='ignore') as f:
    for line in f.read().splitlines():
      if len(line) == 0:
        continue

      split_lines = line.split(",")

      bbox = np.array(split_lines[0:8], dtype=np.int32)
      text = ",".join(split_lines[8:])

      # From the splited line we save (filename, [bounding box points], text line).
      # The filename will be useful in the future
      bbox_and_words_list.append([path.stem, *bbox, text])

  dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
  dataframe = dataframe.drop(columns=['x1', 'y1', 'x3', 'y3'])

  return dataframe


# Example usage
bbox_file_path = sroie_folder_path / "test/box" / example_file
print("== File content ==")
# !head -n 5 "{bbox_file_path}"

bbox = read_bbox_and_words(path=bbox_file_path)
print("\n== Dataframe ==")
bbox.head(5)
# Out:
# == File content ==
# 98,26,321,26,321,66,98,66,TAN CHAY YEE
# 138,95,279,95,279,120,138,120,*** COPY ***
# 80,119,329,119,329,140,80,140,OJC MARKETING SDN BHD
# 129,142,287,142,287,160,129,160,ROC NO: 538358-H
# 104,163,306,163,306,182,104,182,NO 2 & 4, JALAN BAYU 4,
#
# == Dataframe ==
# <ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#        filename   x0   y0   x2   y2                     line
# 0  X00016469670   98   26  321   66             TAN CHAY YEE
# 1  X00016469670  138   95  279  120             *** COPY ***
# 2  X00016469670   80  119  329  140    OJC MARKETING SDN BHD
# 3  X00016469670  129  142  287  160         ROC NO: 538358-H
# 4  X00016469670  104  163  306  182  NO 2 & 4, JALAN BAYU 4,

# %%
def read_entities(path: Path):
  with open(path, 'r') as f:
    data = json.load(f)

  dataframe = pd.DataFrame([data])
  return dataframe


# Example usage
entities_file_path = sroie_folder_path /  "test/entities" / example_file
print("== File content ==")
# !head "{entities_file_path}"

entities = read_entities(path=entities_file_path)
print("\n\n== Dataframe ==")
entities
# Out:
# == File content ==
# {
#     "company": "OJC MARKETING SDN BHD",
#     "date": "15/01/2019",
#     "address": "NO 2 & 4, JALAN BAYU 4, BANDAR SERI ALAM, B1750 MASAI, JOHOR",
#     "total": "193.00"
# }
#
# == Dataframe ==
#                  company        date  \
# 0  OJC MARKETING SDN BHD  15/01/2019
#
#                                              address   total
# 0  NO 2 & 4, JALAN BAYU 4, BANDAR SERI ALAM, B175...  193.00

# %%
# Assign a label to the line by checking the similarity
# of the line and all the entities
def assign_line_label(line: str, entities: pd.DataFrame):
    line_set = line.replace(",", "").strip().split()
    for i, column in enumerate(entities):
        entity_values = entities.iloc[0, i].replace(",", "").strip()
        entity_set = entity_values.split()


        matches_count = 0
        for l in line_set:
            if any(SequenceMatcher(a=l, b=b).ratio() > 0.8 for b in entity_set):
                matches_count += 1

            if (column.upper() == 'ADDRESS' and (matches_count / len(line_set)) >= 0.5) or \
               (column.upper() != 'ADDRESS' and (matches_count == len(line_set))) or \
               matches_count == len(entity_set):
                return column.upper()

    return "O"


line = bbox.loc[1,"line"]
label = assign_line_label(line, entities)
print("Line:", line)
print("Assigned label:", label)
# Out:
# Line: *** COPY ***
# Assigned label: O

# %%
def assign_labels(words: pd.DataFrame, entities: pd.DataFrame):
    max_area = {"TOTAL": (0, -1), "DATE": (0, -1)}  # Value, index
    already_labeled = {"TOTAL": False,
                       "DATE": False,
                       "ADDRESS": False,
                       "COMPANY": False,
                       "O": False
    }

    # Go through every line in $words and assign it a label
    labels = []
    for i, line in enumerate(words['line']):
        label = assign_line_label(line, entities)

        already_labeled[label] = True
        if (label == "ADDRESS" and already_labeled["TOTAL"]) or \
           (label == "COMPANY" and (already_labeled["DATE"] or already_labeled["TOTAL"])):
            label = "O"

        # Assign to the largest bounding box
        if label in ["TOTAL", "DATE"]:
            x0_loc = words.columns.get_loc("x0")
            bbox = words.iloc[i, x0_loc:x0_loc+4].to_list()
            area = (bbox[2] - bbox[0]) + (bbox[3] - bbox[1])

            if max_area[label][0] < area:
                max_area[label] = (area, i)

            label = "O"

        labels.append(label)

    labels[max_area["DATE"][1]] = "DATE"
    labels[max_area["TOTAL"][1]] = "TOTAL"

    words["label"] = labels
    return words


# Example usage
bbox_labeled = assign_labels(bbox, entities)
bbox_labeled.head(15)
# Out:
#         filename   x0   y0   x2   y2                             line    label
# 0   X00016469670   98   26  321   66                     TAN CHAY YEE        O
# 1   X00016469670  138   95  279  120                     *** COPY ***        O
# 2   X00016469670   80  119  329  140            OJC MARKETING SDN BHD  COMPANY
# 3   X00016469670  129  142  287  160                 ROC NO: 538358-H        O
# 4   X00016469670  104  163  306  182          NO 2 & 4, JALAN BAYU 4,  ADDRESS
# 5   X00016469670  123  185  286  205                BANDAR SERI ALAM,  ADDRESS
# 6   X00016469670  116  205  292  223               81750 MASAI, JOHOR  ADDRESS
# 7   X00016469670   69  226  339  248  TEL:07-388 2218 FAX:07-388 8218        O
# 8   X00016469670  110  249  300  272            EMAIL:NG@OJCGROUP.COM        O
# 9   X00016469670  145  291  266  313                      TAX INVOICE        O
# 10  X00016469670   27  326  109  341                       INVOICE NO  ADDRESS
# 11  X00016469670  116  322  259  343                  : PEGIV-1030765        O
# 12  X00016469670   25  347   72  365                             DATE        O
# 13  X00016469670  121  348  326  363         : 15/01/2019 11:05:16 AM     DATE
# 14  X00016469670   20  369   84  387                          CASHIER        O

# %% [markdown]
# Tranforming data to JSON FILE for Label Studio

# %%
import pandas as pd

# create a dataframe
bbox_labeled
# loop through the rows using iterrows()
#for index, row in bbox_labeled.iterrows():
 #   print(row['filename'], row['x0'])
# Out:
#         filename   x0   y0   x2   y2  \
# 0   X00016469670   98   26  321   66
# 1   X00016469670  138   95  279  120
# 2   X00016469670   80  119  329  140
# 3   X00016469670  129  142  287  160
# 4   X00016469670  104  163  306  182
# 5   X00016469670  123  185  286  205
# 6   X00016469670  116  205  292  223
# 7   X00016469670   69  226  339  248
# 8   X00016469670  110  249  300  272
# 9   X00016469670  145  291  266  313
# 10  X00016469670   27  326  109  341
# 11  X00016469670  116  322  259  343
# 12  X00016469670   25  347   72  365
# 13  X00016469670  121  348  326  363
# 14  X00016469670   20  369   84  387
# 15  X00016469670  120  367  253  385
# 16  X00016469670   29  390  180  408
# 17  X00016469670   27  412   71  429
# 18  X00016469670  119  412  365  428
# 19  X00016469670   23  441   87  465
# 20  X00016469670  112  444  140  459
# 21  X00016469670   26  527  114  543
# 22  X00016469670  183  525  210  544
# 23  X00016469670  231  526  274  544
# 24  X00016469670  295  528  357  544
# 25  X00016469670   22  550  105  564
# 26  X00016469670  199  550  215  565
# 27  X00016469670  217  549  271  566
# 28  X00016469670  304  549  383  566
# 29  X00016469670   22  576  254  591
# 30  X00016469670   28  611   73  633
# 31  X00016469670  108  610  250  629
# 32  X00016469670  299  613  354  629
# 33  X00016469670  122  632  252  653
# 34  X00016469670  319  633  357  652
# 35  X00016469670  103  654  253  673
# 36  X00016469670  305  656  357  672
# 37  X00016469670  158  675  251  691
# 38  X00016469670  319  674  357  691
# 39  X00016469670  173  697  240  718
# 40  X00016469670  290  699  355  718
# 41  X00016469670  145  729  231  745
# 42  X00016469670  304  729  356  746
# 43  X00016469670   93  751  228  769
# 44  X00016469670   89  772  231  793
# 45  X00016469670   34  843  371  866
# 46  X00016469670   44  865  362  886
#
#                                           line    label
# 0                                 TAN CHAY YEE        O
# 1                                 *** COPY ***        O
# 2                        OJC MARKETING SDN BHD  COMPANY
# 3                             ROC NO: 538358-H        O
# 4                      NO 2 & 4, JALAN BAYU 4,  ADDRESS
# 5                            BANDAR SERI ALAM,  ADDRESS
# 6                           81750 MASAI, JOHOR  ADDRESS
# 7              TEL:07-388 2218 FAX:07-388 8218        O
# 8                        EMAIL:NG@OJCGROUP.COM        O
# 9                                  TAX INVOICE        O
# 10                                  INVOICE NO  ADDRESS
# 11                             : PEGIV-1030765        O
# 12                                        DATE        O
# 13                    : 15/01/2019 11:05:16 AM     DATE
# 14                                     CASHIER        O
# 15                              : NG CHUAN MIN        O
# 16                        SALES PERSON : FATIN        O
# 17                                     BILL TO        O
# 18                     : THE PEAK QUARRY WORKS        O
# 19                                     ADDRESS        O
# 20                                          :.        O
# 21                                 DESCRIPTION        O
# 22                                         QTY        O
# 23                                       PRICE        O
# 24                                      AMOUNT        O
# 25                                   000000111        O
# 26                                           1        O
# 27                                      193.00        O
# 28                                   193.00 SR    TOTAL
# 29                  KINGS SAFETY SHOES KWD B05        O
# 30                                      QTY: 1        O
# 31                          TOTAL EXCLUDE GST:        O
# 32                                      193.00        O
# 33                              TOTAL GST @6%:        O
# 34                                        0.00        O
# 35                        TOTAL INCLUSIVE GST:        O
# 36                                      193.00        O
# 37                                  ROUND AMT:        O
# 38                                        0.00        O
# 39                                      TOTAL:        O
# 40                                      193.00        O
# 41                                   VISA CARD        O
# 42                                      193.00        O
# 43                            XXXXXXXXXXXX4318        O
# 44                           APPROVAL CODE:000        O
# 45  GOODS SOLD ARE NOT RETURNABLE & REFUNDABLE        O
# 46       ****THANK YOU. PLEASE COME AGAIN.****        O

# %%
import os
import PIL
predictions = []

def row_to_json(row, ogwidth, ogheight,i):
  filename = row["filename"]
  x0 = row["x0"]
  y0 = row["y0"]
  x2 = row["x2"]
  y2 = row["y2"]
  line = row["line"]
  label = row["label"]
  width = row["x2"] - row["x0"]
  height = row["y2"] - row["y0"]
  prediction = {
    "original_width": ogwidth,
    "original_height": ogheight,
    "image_rotation": 0,
    "value": {
        "x": (x0*100)/ogwidth,
        "y": (y0*100)/ogheight,
        "width": (width*100)/ogwidth,
        "height": (height*100)/ogheight,
        "rotation": 0 ,
    },
          "id": filename + "-"  + str(i),
          "from_name": "bbox",
          "to_name": "image",
          "type": "rectangle"
  }
  prediction2 = {
    "original_width": ogwidth,
    "original_height": ogheight,
    "image_rotation": 0,
    "value": {
        "x": (x0*100)/ogwidth,
        "y": (y0*100)/ogheight,
        "width": (width*100)/ogwidth,
        "height": (height*100)/ogheight,
        "rotation": 0 ,
         "labels": [
                     "Text"
                  ]
    },
               "id": filename + "-"  + str(i) ,
               "from_name": "label",
               "to_name": "image",
               "type": "labels"
  }
  prediction3 = {
          "original_width": ogwidth,
    "original_height": ogheight,
    "image_rotation": 0,
    "value": {
        "x": (x0*100)/ogwidth,
        "y": (y0*100)/ogheight,
        "width": (width*100)/ogwidth,
        "height": (height*100)/ogheight,
        "rotation": 0 ,
        "text": [
                     line
                  ]
    },
          "id": filename + "-" + str(i) ,
               "from_name": "transcription",
               "to_name": "image",
               "type": "textarea"
  }
  predictions.append(prediction)
  predictions.append(prediction2)
  predictions.append(prediction3)



class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)


def read_dataframe_json(bbox_labeled,folder):

  last_location =  get_everything_after_sroie2019(folder)
  folder_path = "/content/drive/MyDrive/SROIE2"+ last_location + "/" + 'img/'
  folder_image = "/data/local-files?d=SROIE2" + last_location + "/" + 'img/'
  fileinfolder=bbox_labeled.iloc[0]
  image = PIL.Image.open(folder_path + fileinfolder["filename"] + '.jpg')
  ogwidth, ogheight = image.size # get the width and height in pixels
#for i in range(2): # loop through the first two rows
  for index, row in bbox_labeled.iterrows():

    row_to_json(row, ogwidth, ogheight , index)

  final_dict = { "data": {
          "ocr": folder_image + fileinfolder["filename"] + ".jpg"
      },
                "predictions": [ { "model_version": 1, "result": predictions , "score": 0.89 } ] }
  output_file = "/content/results/" + fileinfolder["filename"] +".json"
  import json
  import numpy as np
  json_object = json.dumps(final_dict,cls=NpEncoder)
  with open(output_file, "w") as outfile:
      outfile.write(json_object)
  predictions.clear()

# %%
from time import perf_counter
def get_everything_after_sroie2019(folder_image):
  folder_image_str = str(folder_image)
  last_component = folder_image_str[-len("SROIE2019"):]
  return last_component

# %%
def dataset_creator(folder: Path):
    bbox_folder = folder / "box"
    entities_folder = folder / "entities"
    entities_files = sorted(entities_folder.glob("*.txt"))
    bbox_files = sorted(Path(bbox_folder).glob("*.txt"))
    for bbox_file, entities_file in tqdm(zip(bbox_files, entities_files), total=len(bbox_files)):
      # Read the files

      bbox = read_bbox_and_words(bbox_file)
      entities = read_entities(entities_file)
      # Assign labels to lines in bbox using entities
      bbox_labeled = assign_labels(bbox, entities)
      del bbox
      read_dataframe_json(bbox_labeled,folder)

# %%
SROIE_path = Path('/content/drive/MyDrive/SROIE2019')
dataset_creator(Path(SROIE_path / 'train' ))
# Out:
#   0%|          | 0/626 [00:00<?, ?it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
# <ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   0%|          | 2/626 [00:00<05:10,  2.01it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   0%|          | 3/626 [00:01<06:24,  1.62it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   1%|          | 4/626 [00:02<06:52,  1.51it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   1%|          | 5/626 [00:03<07:28,  1.38it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   1%|          | 6/626 [00:04<07:48,  1.32it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   1%|          | 7/626 [00:09<22:11,  2.15s/it]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   1%|▏         | 8/626 [00:09<16:43,  1.62s/it]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   1%|▏         | 9/626 [00:10<13:29,  1.31s/it]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   2%|▏         | 10/626 [00:10<10:47,  1.05s/it]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   2%|▏         | 11/626 [00:11<09:26,  1.08it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   2%|▏         | 12/626 [00:12<08:18,  1.23it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   2%|▏         | 13/626 [00:12<07:47,  1.31it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   2%|▏         | 14/626 [00:13<08:13,  1.24it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   2%|▏         | 15/626 [00:14<07:28,  1.36it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   3%|▎         | 16/626 [00:14<06:40,  1.52it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   3%|▎         | 17/626 [00:15<08:08,  1.25it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   3%|▎         | 18/626 [00:16<07:07,  1.42it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   3%|▎         | 19/626 [00:16<06:21,  1.59it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   3%|▎         | 20/626 [00:17<06:00,  1.68it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   3%|▎         | 21/626 [00:17<06:03,  1.66it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   4%|▎         | 22/626 [00:18<06:44,  1.49it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   4%|▎         | 23/626 [00:19<06:23,  1.57it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   4%|▍         | 24/626 [00:19<06:07,  1.64it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   4%|▍         | 25/626 [00:20<06:14,  1.61it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   4%|▍         | 26/626 [00:20<06:03,  1.65it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   4%|▍         | 27/626 [00:21<05:59,  1.67it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   4%|▍         | 28/626 [00:22<06:21,  1.57it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   5%|▍         | 29/626 [00:22<06:34,  1.52it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   5%|▍         | 30/626 [00:23<06:15,  1.59it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   5%|▍         | 31/626 [00:24<05:42,  1.73it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   5%|▌         | 32/626 [00:24<05:27,  1.81it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   5%|▌         | 33/626 [00:25<05:28,  1.80it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   5%|▌         | 34/626 [00:25<05:22,  1.84it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   6%|▌         | 35/626 [00:26<05:19,  1.85it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   6%|▌         | 36/626 [00:26<05:50,  1.68it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   6%|▌         | 37/626 [00:27<06:06,  1.61it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   6%|▌         | 38/626 [00:27<05:36,  1.75it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   6%|▌         | 39/626 [00:28<05:50,  1.67it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   6%|▋         | 40/626 [00:29<05:33,  1.76it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   7%|▋         | 41/626 [00:29<05:25,  1.79it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   7%|▋         | 42/626 [00:30<05:12,  1.87it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   7%|▋         | 43/626 [00:30<05:56,  1.63it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   7%|▋         | 44/626 [00:31<06:16,  1.54it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   7%|▋         | 45/626 [00:32<06:12,  1.56it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   7%|▋         | 46/626 [00:32<05:52,  1.64it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   8%|▊         | 47/626 [00:33<05:34,  1.73it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   8%|▊         | 48/626 [00:33<05:12,  1.85it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   8%|▊         | 49/626 [00:34<06:07,  1.57it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   8%|▊         | 50/626 [00:35<06:24,  1.50it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   8%|▊         | 51/626 [00:35<06:13,  1.54it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   8%|▊         | 52/626 [00:36<05:56,  1.61it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   8%|▊         | 53/626 [00:37<05:29,  1.74it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   9%|▊         | 54/626 [00:37<06:08,  1.55it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   9%|▉         | 55/626 [00:38<05:53,  1.61it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   9%|▉         | 56/626 [00:38<05:39,  1.68it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   9%|▉         | 57/626 [00:39<06:36,  1.44it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   9%|▉         | 58/626 [00:40<06:05,  1.56it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#   9%|▉         | 59/626 [00:40<05:42,  1.65it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  10%|▉         | 60/626 [00:41<05:39,  1.67it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  10%|▉         | 61/626 [00:42<06:15,  1.50it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  10%|▉         | 62/626 [00:42<06:14,  1.51it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  10%|█         | 63/626 [00:43<05:42,  1.64it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  10%|█         | 64/626 [00:43<05:18,  1.77it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  10%|█         | 65/626 [00:44<05:05,  1.84it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  11%|█         | 66/626 [00:45<05:23,  1.73it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  11%|█         | 67/626 [00:45<05:45,  1.62it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  11%|█         | 68/626 [00:46<05:17,  1.76it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  11%|█         | 69/626 [00:46<05:28,  1.70it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  11%|█         | 70/626 [00:47<05:47,  1.60it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  11%|█▏        | 71/626 [00:48<05:30,  1.68it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  12%|█▏        | 72/626 [00:48<05:23,  1.71it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  12%|█▏        | 73/626 [00:49<05:35,  1.65it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  12%|█▏        | 74/626 [00:49<05:39,  1.63it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  12%|█▏        | 75/626 [00:50<05:19,  1.73it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  12%|█▏        | 76/626 [00:51<05:54,  1.55it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  12%|█▏        | 77/626 [00:51<05:45,  1.59it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  12%|█▏        | 78/626 [00:52<05:29,  1.67it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  13%|█▎        | 79/626 [00:52<05:23,  1.69it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  13%|█▎        | 80/626 [00:53<05:07,  1.78it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  13%|█▎        | 81/626 [00:54<05:25,  1.67it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  13%|█▎        | 82/626 [00:54<05:09,  1.76it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  13%|█▎        | 83/626 [00:55<05:03,  1.79it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  13%|█▎        | 84/626 [00:55<04:53,  1.85it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  14%|█▎        | 85/626 [00:56<04:39,  1.94it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  14%|█▎        | 86/626 [00:56<05:10,  1.74it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  14%|█▍        | 87/626 [00:57<05:02,  1.78it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  14%|█▍        | 88/626 [00:57<05:10,  1.73it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  14%|█▍        | 89/626 [00:58<05:50,  1.53it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  14%|█▍        | 90/626 [00:59<05:34,  1.60it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  15%|█▍        | 91/626 [00:59<05:30,  1.62it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  15%|█▍        | 92/626 [01:00<05:45,  1.54it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  15%|█▍        | 93/626 [01:01<05:42,  1.56it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  15%|█▌        | 94/626 [01:02<06:11,  1.43it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  15%|█▌        | 95/626 [01:02<05:34,  1.59it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  15%|█▌        | 96/626 [01:03<05:41,  1.55it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  15%|█▌        | 97/626 [01:03<05:15,  1.68it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  16%|█▌        | 98/626 [01:04<05:36,  1.57it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  16%|█▌        | 99/626 [01:05<05:29,  1.60it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  16%|█▌        | 100/626 [01:05<05:10,  1.69it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  16%|█▌        | 101/626 [01:06<04:57,  1.77it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  16%|█▋        | 102/626 [01:06<04:43,  1.85it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  16%|█▋        | 103/626 [01:07<04:30,  1.94it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  17%|█▋        | 104/626 [01:07<04:41,  1.85it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
# ...
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  95%|█████████▍| 592/626 [06:13<00:16,  2.03it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  95%|█████████▍| 593/626 [06:13<00:16,  2.00it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  95%|█████████▍| 594/626 [06:14<00:16,  1.97it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  95%|█████████▌| 595/626 [06:14<00:15,  2.01it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  95%|█████████▌| 596/626 [06:15<00:14,  2.02it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  95%|█████████▌| 597/626 [06:15<00:14,  2.05it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  96%|█████████▌| 598/626 [06:16<00:13,  2.03it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  96%|█████████▌| 599/626 [06:16<00:16,  1.64it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  96%|█████████▌| 600/626 [06:17<00:15,  1.71it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  96%|█████████▌| 601/626 [06:18<00:15,  1.61it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  96%|█████████▌| 602/626 [06:18<00:15,  1.51it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  96%|█████████▋| 603/626 [06:19<00:14,  1.60it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  96%|█████████▋| 604/626 [06:20<00:13,  1.65it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  97%|█████████▋| 605/626 [06:20<00:13,  1.57it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  97%|█████████▋| 606/626 [06:21<00:12,  1.63it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  97%|█████████▋| 607/626 [06:21<00:11,  1.66it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  97%|█████████▋| 608/626 [06:22<00:11,  1.58it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  97%|█████████▋| 609/626 [06:23<00:10,  1.70it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  97%|█████████▋| 610/626 [06:23<00:09,  1.62it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  98%|█████████▊| 611/626 [06:24<00:09,  1.55it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  98%|█████████▊| 612/626 [06:24<00:08,  1.68it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  98%|█████████▊| 613/626 [06:25<00:07,  1.69it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  98%|█████████▊| 614/626 [06:26<00:06,  1.77it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  98%|█████████▊| 615/626 [06:26<00:05,  1.85it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  98%|█████████▊| 616/626 [06:27<00:05,  1.84it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  99%|█████████▊| 617/626 [06:27<00:05,  1.65it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  99%|█████████▊| 618/626 [06:28<00:05,  1.54it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  99%|█████████▉| 619/626 [06:29<00:04,  1.57it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  99%|█████████▉| 620/626 [06:29<00:04,  1.46it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  99%|█████████▉| 621/626 [06:30<00:03,  1.55it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
#  99%|█████████▉| 622/626 [06:31<00:02,  1.55it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
# 100%|█████████▉| 623/626 [06:31<00:01,  1.65it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
# 100%|█████████▉| 624/626 [06:32<00:01,  1.72it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
# 100%|█████████▉| 625/626 [06:32<00:00,  1.87it/s]<ipython-input-3-017e64e99498>:18: FutureWarning: Could not cast to int16, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   dataframe = pd.DataFrame(bbox_and_words_list, columns=['filename', 'x0', 'y0', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'line'], dtype=np.int16)
# 100%|██████████| 626/626 [06:33<00:00,  1.59it/s]

# %% [markdown]
# set LABEL_STUDIO_LOCAL_FILES_SERVING_ENABLED=true
# set LABEL_STUDIO_LOCAL_FILES_DOCUMENT_ROOT=C:\Users\Yeyian PC\Documents\SROIEDATASET

# %% [markdown]
# ==============================================================================================================================================================================================================================================

# %%
# !zip -r '/content/results' '/content/results'
# Out:
#   adding: content/results/ (stored 0%)
#   adding: content/results/X51006557164.json (deflated 94%)
#   adding: content/results/X51008142062.json (deflated 94%)
#   adding: content/results/X51006619566.json (deflated 91%)
#   adding: content/results/X51006557193.json (deflated 93%)
#   adding: content/results/X51006828217.json (deflated 93%)
#   adding: content/results/X51008114281.json (deflated 92%)
#   adding: content/results/X51005711442.json (deflated 93%)
#   adding: content/results/X51006913031.json (deflated 91%)
#   adding: content/results/X51006414394.json (deflated 93%)
#   adding: content/results/X51007339158.json (deflated 92%)
#   adding: content/results/X51006556815.json (deflated 94%)
#   adding: content/results/X51006619697.json (deflated 93%)
#   adding: content/results/X51005715456.json (deflated 93%)
#   adding: content/results/X51006414638.json (deflated 93%)
#   adding: content/results/X51008164991.json (deflated 93%)
#   adding: content/results/X51006913070.json (deflated 92%)
#   adding: content/results/X51006414431.json (deflated 91%)
#   adding: content/results/X51008142031.json (deflated 93%)
#   adding: content/results/X51006556839.json (deflated 94%)
#   adding: content/results/X51005663276.json (deflated 93%)
#   adding: content/results/X51008142033.json (deflated 93%)
#   adding: content/results/X51005361907.json (deflated 93%)
#   adding: content/results/X51006387932.json (deflated 93%)
#   adding: content/results/X51006414675.json (deflated 92%)
#   adding: content/results/X51005568884.json (deflated 92%)
#   adding: content/results/X51005806678.json (deflated 92%)
#   adding: content/results/X51006619496.json (deflated 93%)
#   adding: content/results/X51006913055.json (deflated 92%)
#   adding: content/results/X51005365179.json (deflated 93%)
#   adding: content/results/X51005745188.json (deflated 93%)
#   adding: content/results/X51008123446.json (deflated 91%)
#   adding: content/results/X51006912972.json (deflated 91%)
#   adding: content/results/X51007103641.json (deflated 93%)
#   adding: content/results/X51008142065.json (deflated 94%)
#   adding: content/results/X51005757323.json (deflated 93%)
#   adding: content/results/X51006554833.json (deflated 94%)
#   adding: content/results/X51006557178.json (deflated 94%)
#   adding: content/results/X51008042782.json (deflated 93%)
#   adding: content/results/X51006913007.json (deflated 92%)
#   adding: content/results/X51007339111.json (deflated 92%)
#   adding: content/results/X51008030566.json (deflated 93%)
#   adding: content/results/X51007846398.json (deflated 92%)
#   adding: content/results/X51006556824.json (deflated 94%)
#   adding: content/results/X00016469620.json (deflated 93%)
#   adding: content/results/X51005447860.json (deflated 93%)
#   adding: content/results/X51006557119.json (deflated 94%)
#   adding: content/results/X51007339164.json (deflated 92%)
#   adding: content/results/X51007103675.json (deflated 93%)
#   adding: content/results/X51005568827.json (deflated 93%)
#   adding: content/results/X51006557117.json (deflated 94%)
#   adding: content/results/X51005676540.json (deflated 94%)
#   adding: content/results/X51005433492.json (deflated 93%)
#   adding: content/results/X51006913051.json (deflated 92%)
#   adding: content/results/X51007846326.json (deflated 92%)
#   adding: content/results/X51007339150.json (deflated 93%)
#   adding: content/results/X51007339162.json (deflated 92%)
#   adding: content/results/X51008142038.json (deflated 92%)
#   adding: content/results/X51006679216.json (deflated 93%)
#   adding: content/results/X51005442333.json (deflated 93%)
#   adding: content/results/X51006327976.json (deflated 92%)
#   adding: content/results/X51007846269.json (deflated 92%)
#   adding: content/results/X51006414719.json (deflated 92%)
#   adding: content/results/X51006441473.json (deflated 93%)
#   adding: content/results/X51006414483.json (deflated 91%)
#   adding: content/results/X51005447850.json (deflated 92%)
#   adding: content/results/X51007339097.json (deflated 93%)
#   adding: content/results/X51005447853.json (deflated 92%)
#   adding: content/results/X51005587267.json (deflated 93%)
#   adding: content/results/X51006466055.json (deflated 94%)
#   adding: content/results/X51006311778.json (deflated 93%)
#   adding: content/results/X51008164420.json (deflated 93%)
#   adding: content/results/X51006414485.json (deflated 91%)
#   adding: content/results/X51005757235.json (deflated 93%)
#   adding: content/results/X51005268262.json (deflated 92%)
#   adding: content/results/X51005453804.json (deflated 93%)
#   adding: content/results/X51009453804.json (deflated 93%)
#   adding: content/results/X51008142060.json (deflated 93%)
#   adding: content/results/X51006466062.json (deflated 93%)
#   adding: content/results/X51005711401.json (deflated 93%)
#   adding: content/results/X51008099049.json (deflated 93%)
#   adding: content/results/X51008123580.json (deflated 93%)
#   adding: content/results/X51006557184.json (deflated 94%)
#   adding: content/results/X51005568829.json (deflated 94%)
#   adding: content/results/X51006867436.json (deflated 93%)
#   adding: content/results/X51007339146.json (deflated 92%)
#   adding: content/results/X51005749912.json (deflated 93%)
#   adding: content/results/X51005746140.json (deflated 93%)
#   adding: content/results/X51006466066.json (deflated 93%)
#   adding: content/results/X51006557185.json (deflated 94%)
#   adding: content/results/X51005433538.json (deflated 93%)
#   adding: content/results/X51007339642.json (deflated 93%)
#   adding: content/results/X51008142063.json (deflated 94%)
#   adding: content/results/X51006414713.json (deflated 93%)
#   adding: content/results/X51007103688.json (deflated 92%)
#   adding: content/results/X51005605284.json (deflated 93%)
#   adding: content/results/X51005745214.json (deflated 92%)
#   adding: content/results/X51006388065.json (deflated 92%)
#   adding: content/results/X51005757248.json (deflated 93%)
#   adding: content/results/X51008123476.json (deflated 92%)
#   adding: content/results/X51007339095.json (deflated 93%)
#   adding: content/results/X51006008095.json (deflated 93%)
#   adding: content/results/X51005663272.json (deflated 93%)
#   adding: content/results/X51005568914.json (deflated 92%)
#   adding: content/results/X51006857071.json (deflated 93%)
#   adding: content/results/X51005677339.json (deflated 93%)
#   adding: content/results/X51005442346.json (deflated 94%)
#   adding: content/results/X51006393377.json (deflated 93%)
#   adding: content/results/X51005719814.json (deflated 93%)
#   adding: content/results/X51007231361.json (deflated 93%)
#   adding: content/results/X51008142068.json (deflated 94%)
#   adding: content/results/X51005442383.json (deflated 94%)
#   adding: content/results/X51008128062.json (deflated 93%)
#   adding: content/results/X51006414720.json (deflated 92%)
#   adding: content/results/X51008164992.json (deflated 93%)
#   adding: content/results/X51007231365.json (deflated 92%)
#   adding: content/results/X51008164525.json (deflated 93%)
#   adding: content/results/X51008064061.json (deflated 93%)
#   adding: content/results/X51008123586.json (deflated 93%)
#   adding: content/results/X51005745190.json (deflated 94%)
#   adding: content/results/X51005605286.json (deflated 92%)
#   adding: content/results/X51006556841.json (deflated 94%)
#   adding: content/results/X51006414470.json (deflated 91%)
#   adding: content/results/X51005442379.json (deflated 93%)
#   adding: content/results/X51007846301.json (deflated 92%)
#   adding: content/results/X51006311779.json (deflated 92%)
#   adding: content/results/X51008128065.json (deflated 92%)
#   adding: content/results/X51007339113.json (deflated 93%)
#   adding: content/results/X51007339132.json (deflated 93%)
#   adding: content/results/X51007339126.json (deflated 92%)
#   adding: content/results/X51006329402.json (deflated 92%)
#   adding: content/results/X51008123450.json (deflated 91%)
#   adding: content/results/X51005442376.json (deflated 93%)
#   adding: content/results/X51005724621.json (deflated 93%)
#   adding: content/results/X51008114260.json (deflated 91%)
#   adding: content/results/X51005719902.json (deflated 93%)
#   adding: content/results/X51005337872.json (deflated 93%)
#   adding: content/results/X51007579726.json (deflated 93%)
#   adding: content/results/X51005757199.json (deflated 92%)
#   adding: content/results/X51006913054.json (deflated 92%)
#   adding: content/results/X51008099084.json (deflated 93%)
#   adding: content/results/X51007135247.json (deflated 93%)
#   adding: content/results/X51005719914.json (deflated 94%)
#   adding: content/results/X51007339156.json (deflated 93%)
#   adding: content/results/X51005724554.json (deflated 93%)
#   adding: content/results/X51005719856.json (deflated 93%)
#   adding: content/results/X51006414721.json (deflated 92%)
#   adding: content/results/X51007103643.json (deflated 94%)
#   adding: content/results/X51006389893.json (deflated 93%)
#   adding: content/results/X51006414392.json (deflated 92%)
#   adding: content/results/X51006328920.json (deflated 92%)
#   adding: content/results/X51008042793.json (deflated 92%)
#   adding: content/results/X51006466065.json (deflated 92%)
#   adding: content/results/X51006912960.json (deflated 92%)
#   adding: content/results/X51006913068.json (deflated 91%)
#   adding: content/results/X51006556730.json (deflated 93%)
#   adding: content/results/X51005568911.json (deflated 93%)
#   adding: content/results/X51006414714.json (deflated 92%)
#   adding: content/results/X51005719873.json (deflated 93%)
#   adding: content/results/X51005757294.json (deflated 92%)
#   adding: content/results/X51005722699.json (deflated 92%)
#   adding: content/results/X51005453802.json (deflated 93%)
#   adding: content/results/X51007339139.json (deflated 92%)
#   adding: content/results/X51006556818.json (deflated 94%)
#   adding: content/results/X51006332649.json (deflated 93%)
#   adding: content/results/X00016469676.json (deflated 92%)
#   adding: content/results/X51006393376.json (deflated 92%)
#   adding: content/results/X51006008073.json (deflated 93%)
#   adding: content/results/X51007846350.json (deflated 92%)
#   adding: content/results/X51005663298.json (deflated 93%)
#   adding: content/results/X51007339131.json (deflated 92%)
#   adding: content/results/X51005447840.json (deflated 94%)
#   adding: content/results/X51008123447.json (deflated 92%)
#   adding: content/results/X51006556738.json (deflated 94%)
#   adding: content/results/X51008114321.json (deflated 93%)
#   adding: content/results/X51006414679.json (deflated 92%)
#   adding: content/results/X51008099087.json (deflated 93%)
#   adding: content/results/X51005361895.json (deflated 92%)
#   adding: content/results/X51005719874.json (deflated 92%)
#   adding: content/results/X51005605333.json (deflated 92%)
#   adding: content/results/X51008114282.json (deflated 92%)
#   adding: content/results/X51005676543.json (deflated 94%)
#   adding: content/results/X51006619561.json (deflated 93%)
#   adding: content/results/X51005200938.json (deflated 94%)
#   adding: content/results/X51006557161.json (deflated 94%)
#   adding: content/results/X51005705804.json (deflated 92%)
#   adding: content/results/X51005685355.json (deflated 94%)
#   adding: content/results/X51005757290.json (deflated 92%)
#   adding: content/results/X51005677334.json (deflated 94%)
#   adding: content/results/X51006392313.json (deflated 93%)
#   adding: content/results/X51006441474.json (deflated 93%)
#   adding: content/results/X51006557210.json (deflated 94%)
#   adding: content/results/X51005676538.json (deflated 94%)
#   adding: content/results/X51007103702.json (deflated 93%)
#   adding: content/results/X51006329395.json (deflated 92%)
#   adding: content/results/X51006555125.json (deflated 92%)
#   adding: content/results/X51007231370.json (deflated 92%)
#   adding: content/results/X51006414703.json (deflated 93%)
#   adding: content/results/X51005711404.json (deflated 94%)
#   adding: content/results/X51005301659.json (deflated 92%)
#   adding: content/results/X51006350763.json (deflated 93%)
#   adding: content/results/X00016469669.json (deflated 92%)
#   adding: content/results/X51005745183.json (deflated 93%)
#   adding: content/results/X51007846451.json (deflated 92%)
#   adding: content/results/X51005361883.json (deflated 93%)
#   adding: content/results/X51008142058.json (deflated 94%)
#   adding: content/results/X51006556831.json (deflated 94%)
#   adding: content/results/X51005442384.json (deflated 93%)
#   adding: content/results/X51008164510.json (deflated 92%)
#   adding: content/results/X51007339117.json (deflated 92%)
#   adding: content/results/X51007339657.json (deflated 93%)
#   adding: content/results/X51007339643.json (deflated 93%)
#   adding: content/results/X51007262315.json (deflated 93%)
#   adding: content/results/X51005361898.json (deflated 92%)
#   adding: content/results/X51007339151.json (deflated 93%)
#   adding: content/results/X51007846412.json (deflated 92%)
#   adding: content/results/X51006714065.json (deflated 92%)
#   adding: content/results/X51006392299.json (deflated 93%)
#   adding: content/results/X51006556828.json (deflated 94%)
#   adding: content/results/X51007846309.json (deflated 92%)
#   adding: content/results/X51006414599.json (deflated 92%)
#   adding: content/results/X51005685357.json (deflated 92%)
#   adding: content/results/X51006620190.json (deflated 92%)
#   adding: content/results/X51005676546.json (deflated 94%)
#   adding: content/results/X51009453801.json (deflated 92%)
#   adding: content/results/X51005676544.json (deflated 93%)
#   adding: content/results/X51006619341.json (deflated 92%)
#   adding: content/results/X51007339157.json (deflated 93%)
#   adding: content/results/X51007339098.json (deflated 93%)
#   adding: content/results/X00016469672.json (deflated 94%)
#   adding: content/results/X51006557179.json (deflated 94%)
#   adding: content/results/X51006311780.json (deflated 94%)
#   adding: content/results/X51007262328.json (deflated 94%)
#   adding: content/results/X51005757201.json (deflated 94%)
#   adding: content/results/X51008030565.json (deflated 93%)
#   adding: content/results/X51006555818.json (deflated 94%)
#   adding: content/results/X51005719912.json (deflated 93%)
#   adding: content/results/X51008099048.json (deflated 93%)
#   adding: content/results/X51005441408.json (deflated 93%)
#   adding: content/results/X51006556830.json (deflated 94%)
#   adding: content/results/X51005719893.json (deflated 93%)
#   adding: content/results/X51006713996.json (deflated 92%)
#   adding: content/results/X51008122920.json (deflated 93%)
#   adding: content/results/X51007339130.json (deflated 93%)
#   adding: content/results/X51005742068.json (deflated 91%)
#   adding: content/results/X51007846305.json (deflated 93%)
#   adding: content/results/X51005442338.json (deflated 94%)
#   adding: content/results/X51006328919.json (deflated 92%)
#   adding: content/results/X51005757351.json (deflated 92%)
#   adding: content/results/X51008128052.json (deflated 93%)
#   adding: content/results/X51005719883.json (deflated 92%)
#   adding: content/results/X51005749905.json (deflated 93%)
#   adding: content/results/X51005268472.json (deflated 94%)
#   adding: content/results/X51005749895.json (deflated 93%)
#   adding: content/results/X00016469623.json (deflated 93%)
#   adding: content/results/X51006327978.json (deflated 93%)
#   adding: content/results/X51005676541.json (deflated 93%)
#   adding: content/results/X51007339639.json (deflated 93%)
#   adding: content/results/X51005568900.json (deflated 92%)
#   adding: content/results/X51005442397.json (deflated 93%)
#   adding: content/results/X51005442341.json (deflated 92%)
#   adding: content/results/X51005757243.json (deflated 93%)
#   adding: content/results/X51008142059.json (deflated 93%)
#   adding: content/results/X51007846302.json (deflated 93%)
#   adding: content/results/X51006556825.json (deflated 94%)
#   adding: content/results/X51007103578.json (deflated 94%)
#   adding: content/results/X51006008197.json (deflated 92%)
#   adding: content/results/X51007103639.json (deflated 93%)
#   adding: content/results/X51005587254.json (deflated 92%)
#   adding: content/results/X51005677328.json (deflated 93%)
#   adding: content/results/X51006414712.json (deflated 93%)
#   adding: content/results/X51005663279.json (deflated 93%)
#   adding: content/results/X51007843145.json (deflated 92%)
#   adding: content/results/X51005757286.json (deflated 93%)
#   adding: content/results/X51006414671.json (deflated 92%)
#   adding: content/results/X51005711451.json (deflated 93%)
#   adding: content/results/X51005806716.json (deflated 94%)
#   adding: content/results/X51006008074.json (deflated 93%)
#   adding: content/results/X51007339648.json (deflated 93%)
#   adding: content/results/X51006913023.json (deflated 92%)
#   adding: content/results/X51006335314.json (deflated 93%)
#   adding: content/results/X51007339647.json (deflated 93%)
#   adding: content/results/X51007846391.json (deflated 92%)
#   adding: content/results/X51007103691.json (deflated 92%)
#   adding: content/results/X51007339120.json (deflated 93%)
#   adding: content/results/X51005705722.json (deflated 93%)
#   adding: content/results/X51006620189.json (deflated 93%)
#   adding: content/results/X51006389865.json (deflated 93%)
#   adding: content/results/X51005663280.json (deflated 92%)
#   adding: content/results/X51008114216.json (deflated 92%)
#   adding: content/results/X51006389888.json (deflated 93%)
#   adding: content/results/X51006350750.json (deflated 93%)
#   adding: content/results/X51007846395.json (deflated 91%)
#   adding: content/results/X51007339100.json (deflated 92%)
#   adding: content/results/X51005442344.json (deflated 94%)
#   adding: content/results/X51005433552.json (deflated 93%)
#   adding: content/results/X51006619862.json (deflated 92%)
#   adding: content/results/X51006555072.json (deflated 93%)
#   adding: content/results/X51007339653.json (deflated 93%)
#   adding: content/results/X51005268200.json (deflated 93%)
#   adding: content/results/X51006008089.json (deflated 93%)
#   adding: content/results/X51006556838.json (deflated 94%)
#   adding: content/results/X51005442394.json (deflated 93%)
#   adding: content/results/X51005712021.json (deflated 94%)
#   adding: content/results/X51006311767.json (deflated 94%)
#   adding: content/results/X51005712039.json (deflated 93%)
#   adding: content/results/X51007231374.json (deflated 92%)
#   adding: content/results/X51005711453.json (deflated 92%)
#   adding: content/results/X51006414519.json (deflated 92%)
#   adding: content/results/X51008114217.json (deflated 93%)
#   adding: content/results/X51006392122.json (deflated 92%)
#   adding: content/results/X51005663324.json (deflated 94%)
#   adding: content/results/X51006556650.json (deflated 95%)
#   adding: content/results/X51005677331.json (deflated 93%)
#   adding: content/results/X51005719904.json (deflated 93%)
#   adding: content/results/X51006008086.json (deflated 92%)
#   adding: content/results/X51005568881.json (deflated 93%)
#   adding: content/results/X51007339152.json (deflated 92%)
#   adding: content/results/X51007846286.json (deflated 92%)
#   adding: content/results/X51005711441.json (deflated 93%)
#   adding: content/results/X51007339135.json (deflated 92%)
#   adding: content/results/X51007339650.json (deflated 92%)
#   adding: content/results/X51007846357.json (deflated 92%)
#   adding: content/results/X51005444045.json (deflated 91%)
#   adding: content/results/X51006619709.json (deflated 93%)
#   adding: content/results/X51007339133.json (deflated 93%)
#   adding: content/results/X51005447832.json (deflated 94%)
#   adding: content/results/X51008099054.json (deflated 93%)
#   adding: content/results/X51007339094.json (deflated 92%)
#   adding: content/results/X51005676545.json (deflated 94%)
#   adding: content/results/X51005433514.json (deflated 93%)
#   adding: content/results/X51006620187.json (deflated 93%)
#   adding: content/results/X51006414636.json (deflated 92%)
#   adding: content/results/X51005453729.json (deflated 93%)
#   adding: content/results/X51005677335.json (deflated 93%)
#   adding: content/results/X51006392273.json (deflated 93%)
#   adding: content/results/X51005676539.json (deflated 93%)
#   adding: content/results/X51005711452.json (deflated 93%)
#   adding: content/results/X51006414711.json (deflated 93%)
#   adding: content/results/X51006387951.json (deflated 92%)
#   adding: content/results/X51006557213.json (deflated 94%)
#   adding: content/results/X51006555780.json (deflated 94%)
#   adding: content/results/X51006387812.json (deflated 94%)
#   adding: content/results/X51006414718.json (deflated 92%)
#   adding: content/results/X51006311758.json (deflated 93%)
#   adding: content/results/X51006556604.json (deflated 94%)
#   adding: content/results/X51008142005.json (deflated 93%)
#   adding: content/results/X51006556656.json (deflated 94%)
#   adding: content/results/X51005268400.json (deflated 93%)
#   adding: content/results/X51006466778.json (deflated 93%)
#   adding: content/results/X51007846388.json (deflated 91%)
#   adding: content/results/X51006387971.json (deflated 92%)
#   adding: content/results/X51005711456.json (deflated 94%)
#   adding: content/results/X51005301667.json (deflated 93%)
#   adding: content/results/X51005806698.json (deflated 93%)
#   adding: content/results/X51005568913.json (deflated 93%)
#   adding: content/results/X51006401978.json (deflated 92%)
#   adding: content/results/X51006414633.json (deflated 92%)
#   adding: content/results/X51007339112.json (deflated 92%)
#   adding: content/results/X51006619783.json (deflated 93%)
#   adding: content/results/X51005447839.json (deflated 93%)
#   adding: content/results/X51007262330.json (deflated 94%)
#   adding: content/results/X51006913059.json (deflated 92%)
#   adding: content/results/X51005255805.json (deflated 93%)
#   adding: content/results/X51005303661.json (deflated 93%)
#   adding: content/results/X51006388066.json (deflated 93%)
#   adding: content/results/X51005663311.json (deflated 93%)
#   adding: content/results/X51006733494.json (deflated 93%)
#   adding: content/results/X51005722668.json (deflated 93%)
#   adding: content/results/X51008099102.json (deflated 93%)
#   adding: content/results/X51007846410.json (deflated 93%)
#   adding: content/results/X51005757324.json (deflated 93%)
#   adding: content/results/X51006555806.json (deflated 94%)
#   adding: content/results/X51006332575.json (deflated 92%)
#   adding: content/results/X51007225417.json (deflated 93%)
#   adding: content/results/X51005705760.json (deflated 93%)
#   adding: content/results/X51006619772.json (deflated 93%)
#   adding: content/results/X51006619550.json (deflated 93%)
#   adding: content/results/X51008042791.json (deflated 93%)
#   adding: content/results/X51005444033.json (deflated 92%)
#   adding: content/results/X51005711447.json (deflated 93%)
#   adding: content/results/X51008164999.json (deflated 93%)
#   adding: content/results/X51008114266.json (deflated 92%)
#   adding: content/results/X51005605334.json (deflated 92%)
#   adding: content/results/X51005230617.json (deflated 93%)
#   adding: content/results/X51006912974.json (deflated 91%)
#   adding: content/results/X51005719886.json (deflated 92%)
#   adding: content/results/X51005442392.json (deflated 93%)
#   adding: content/results/X51007225398.json (deflated 93%)
#   adding: content/results/X51007339110.json (deflated 93%)
#   adding: content/results/X51005719882.json (deflated 92%)
#   adding: content/results/X51008145504.json (deflated 94%)
#   adding: content/results/X51006556726.json (deflated 94%)
#   adding: content/results/X51005741944.json (deflated 93%)
#   adding: content/results/X51005724627.json (deflated 94%)
#   adding: content/results/X51006401723.json (deflated 93%)
#   adding: content/results/X51005677332.json (deflated 93%)
#   adding: content/results/X51006388064.json (deflated 93%)
#   adding: content/results/X51005675095.json (deflated 93%)
#   adding: content/results/X51005447848.json (deflated 93%)
#   adding: content/results/X51006349086.json (deflated 93%)
#   adding: content/results/X51006556840.json (deflated 93%)
#   adding: content/results/X51006913074.json (deflated 92%)
#   adding: content/results/X51005663278.json (deflated 93%)
#   adding: content/results/X51005441398.json (deflated 93%)
#   adding: content/results/X51006555784.json (deflated 94%)
#   adding: content/results/X51006414533.json (deflated 91%)
#   adding: content/results/X51006414700.json (deflated 92%)
#   adding: content/results/X51006620191.json (deflated 93%)
#   adding: content/results/X51006387813.json (deflated 94%)
#   adding: content/results/X51006388082.json (deflated 92%)
#   adding: content/results/X51008099071.json (deflated 93%)
#   adding: content/results/X51005433533.json (deflated 94%)
#   adding: content/results/X51006502531.json (deflated 92%)
#   adding: content/results/X51008142034.json (deflated 93%)
#   adding: content/results/X51008099085.json (deflated 94%)
#   adding: content/results/X51006857265.json (deflated 93%)
#   adding: content/results/X51005447833.json (deflated 93%)
#   adding: content/results/X51007231344.json (deflated 92%)
#   adding: content/results/X51005663297.json (deflated 94%)
#   adding: content/results/X51005757273.json (deflated 92%)
#   adding: content/results/X51006619696.json (deflated 91%)
#   adding: content/results/X51005442378.json (deflated 93%)
#   adding: content/results/X51005301661.json (deflated 94%)
#   adding: content/results/X00016469622.json (deflated 93%)
#   adding: content/results/X51006335547.json (deflated 92%)
#   adding: content/results/X51005676536.json (deflated 93%)
#   adding: content/results/X51007846366.json (deflated 92%)
#   adding: content/results/X51006008057.json (deflated 94%)
#   adding: content/results/X51008142061.json (deflated 94%)
#   adding: content/results/X51007135037.json (deflated 93%)
#   adding: content/results/X51007339115.json (deflated 92%)
#   adding: content/results/X51008114262.json (deflated 92%)
#   adding: content/results/X51007846307.json (deflated 92%)
#   adding: content/results/X51006328913.json (deflated 93%)
#   adding: content/results/X51008099083.json (deflated 93%)
#   adding: content/results/X51008099044.json (deflated 94%)
#   adding: content/results/X51006619785.json (deflated 94%)
#   adding: content/results/X51005361946.json (deflated 92%)
#   adding: content/results/X51005711454.json (deflated 93%)
#   adding: content/results/X51006619545.json (deflated 94%)
#   adding: content/results/X51005757304.json (deflated 92%)
#   adding: content/results/X51007339651.json (deflated 93%)
#   adding: content/results/X51005433541.json (deflated 93%)
#   adding: content/results/X51005361950.json (deflated 91%)
#   adding: content/results/X51006414680.json (deflated 92%)
#   adding: content/results/X51007846368.json (deflated 94%)
#   adding: content/results/X51007225442.json (deflated 93%)
#   adding: content/results/X51007339167.json (deflated 92%)
#   adding: content/results/X51005605285.json (deflated 92%)
#   adding: content/results/X51007846353.json (deflated 93%)
#   adding: content/results/X51006856981.json (deflated 93%)
#   adding: content/results/X51005745296.json (deflated 94%)
#   adding: content/results/X51005568891.json (deflated 94%)
#   adding: content/results/X51008123599.json (deflated 93%)
#   adding: content/results/X51005453801.json (deflated 93%)
#   adding: content/results/X51008063849.json (deflated 92%)
#   adding: content/results/X51007339656.json (deflated 93%)
#   adding: content/results/X51005763940.json (deflated 93%)
#   adding: content/results/X51008164969.json (deflated 93%)
#   adding: content/results/X00016469612.json (deflated 93%)
#   adding: content/results/X51006555570.json (deflated 94%)
#   adding: content/results/X51006867435.json (deflated 93%)
#   adding: content/results/X51005889296.json (deflated 92%)
#   adding: content/results/X51005715451.json (deflated 93%)
#   adding: content/results/X51005663277.json (deflated 93%)
#   adding: content/results/X51006466060.json (deflated 92%)
#   adding: content/results/X51005441407.json (deflated 93%)
#   adding: content/results/X51008099089.json (deflated 93%)
#   adding: content/results/X51005711403.json (deflated 93%)
#   adding: content/results/X51006387953.json (deflated 93%)
#   adding: content/results/X51006556861.json (deflated 94%)
#   adding: content/results/X51007339114.json (deflated 92%)
#   adding: content/results/X51006387847.json (deflated 93%)
#   adding: content/results/X51007231336.json (deflated 91%)
#   adding: content/results/X51007339165.json (deflated 92%)
#   adding: content/results/X51007846393.json (deflated 92%)
#   adding: content/results/X51006557170.json (deflated 94%)
#   adding: content/results/X51006387740.json (deflated 93%)
#   adding: content/results/X51005441401.json (deflated 93%)
#   adding: content/results/X51005441402.json (deflated 93%)
#   adding: content/results/X51005719899.json (deflated 93%)
#   adding: content/results/X51008164998.json (deflated 93%)
#   adding: content/results/X51006619758.json (deflated 92%)
#   adding: content/results/X51008042777.json (deflated 93%)
#   adding: content/results/X51008099081.json (deflated 93%)
#   adding: content/results/X51005806703.json (deflated 94%)
#   adding: content/results/X51005361900.json (deflated 93%)
#   adding: content/results/X51005757353.json (deflated 93%)
#   adding: content/results/X51006334699.json (deflated 93%)
#   adding: content/results/X51006620181.json (deflated 92%)
#   adding: content/results/X51008042783.json (deflated 91%)
#   adding: content/results/X51005711445.json (deflated 93%)
#   adding: content/results/X51007231338.json (deflated 93%)
#   adding: content/results/X51006311764.json (deflated 92%)
#   adding: content/results/X51008145450.json (deflated 94%)
#   adding: content/results/X51006619694.json (deflated 93%)
#   adding: content/results/X51006556591.json (deflated 94%)
#   adding: content/results/X51006334926.json (deflated 93%)
#   adding: content/results/X51005433553.json (deflated 94%)
#   adding: content/results/X51006401836.json (deflated 92%)
#   adding: content/results/X51007846370.json (deflated 91%)
#   adding: content/results/X51005724629.json (deflated 94%)
#   adding: content/results/X51006414733.json (deflated 93%)
#   adding: content/results/X51005447861.json (deflated 93%)
#   adding: content/results/X51005676549.json (deflated 93%)
#   adding: content/results/X51008164997.json (deflated 93%)
#   adding: content/results/X51006619343.json (deflated 93%)
#   adding: content/results/X51005663273.json (deflated 93%)
#   adding: content/results/X51008114283.json (deflated 92%)
#   adding: content/results/X51008142032.json (deflated 93%)
#   adding: content/results/X51007225399.json (deflated 93%)
#   adding: content/results/X51006557199.json (deflated 94%)
#   adding: content/results/X51006913073.json (deflated 92%)
#   adding: content/results/X51006414631.json (deflated 93%)
#   adding: content/results/X51008142030.json (deflated 93%)
#   adding: content/results/X51008099046.json (deflated 93%)
#   adding: content/results/X51006556852.json (deflated 94%)
#   adding: content/results/X51006619777.json (deflated 92%)
#   adding: content/results/X51005306399.json (deflated 93%)
#   adding: content/results/X51005719864.json (deflated 93%)
#   adding: content/results/X51006502529.json (deflated 92%)
#   adding: content/results/X51005442386.json (deflated 93%)
#   adding: content/results/X51007339136.json (deflated 93%)
#   adding: content/results/X51005715010.json (deflated 93%)
#   adding: content/results/X51007339166.json (deflated 92%)
#   adding: content/results/X51006334741.json (deflated 93%)
#   adding: content/results/X51007846325.json (deflated 93%)
#   adding: content/results/X51005757349.json (deflated 92%)
#   adding: content/results/X51006555814.json (deflated 94%)
#   adding: content/results/X51006388069.json (deflated 93%)
#   adding: content/results/X51006679222.json (deflated 93%)
#   adding: content/results/X51006401869.json (deflated 93%)
#   adding: content/results/X51006619780.json (deflated 92%)
#   adding: content/results/X51006329399.json (deflated 93%)
#   adding: content/results/X51006647932.json (deflated 93%)
#   adding: content/results/X51005712038.json (deflated 94%)
#   adding: content/results/X51006620414.json (deflated 93%)
#   adding: content/results/X51006008091.json (deflated 93%)
#   adding: content/results/X51006414674.json (deflated 92%)
#   adding: content/results/X51008164996.json (deflated 94%)
#   adding: content/results/X51006389884.json (deflated 93%)
#   adding: content/results/X51005568898.json (deflated 94%)
#   adding: content/results/X51008099043.json (deflated 93%)
#   adding: content/results/X51006556732.json (deflated 94%)
#   adding: content/results/X51005719906.json (deflated 92%)
#   adding: content/results/X51005676547.json (deflated 94%)
#   adding: content/results/X51005442327.json (deflated 93%)
#   adding: content/results/X51007103692.json (deflated 94%)
#   adding: content/results/X51006555817.json (deflated 95%)
#   adding: content/results/X51005712017.json (deflated 92%)
#   adding: content/results/X51007846270.json (deflated 93%)
#   adding: content/results/X51006557508.json (deflated 94%)
#   adding: content/results/X51006556646.json (deflated 94%)
#   adding: content/results/X51006913024.json (deflated 91%)
#   adding: content/results/X51006619698.json (deflated 92%)
#   adding: content/results/X51005447852.json (deflated 92%)
#   adding: content/results/X51006414429.json (deflated 92%)
#   adding: content/results/X51006620161.json (deflated 93%)
#   adding: content/results/X51008099073.json (deflated 93%)
#   adding: content/results/X51006557198.json (deflated 95%)
#   adding: content/results/X51005663317.json (deflated 93%)
#   adding: content/results/X51006556596.json (deflated 93%)
#   adding: content/results/X51006913030.json (deflated 92%)
#   adding: content/results/X51006557168.json (deflated 94%)
#   adding: content/results/X51005568899.json (deflated 92%)
#   adding: content/results/X51007103599.json (deflated 92%)
#   adding: content/results/X51005442361.json (deflated 94%)
#   adding: content/results/X51008042778.json (deflated 93%)
#   adding: content/results/X51005719917.json (deflated 93%)
#   adding: content/results/X51006502533.json (deflated 93%)
#   adding: content/results/X51005663301.json (deflated 92%)
#   adding: content/results/X51008145505.json (deflated 93%)
#   adding: content/results/X51008123604.json (deflated 93%)
#   adding: content/results/X51005806679.json (deflated 94%)
#   adding: content/results/X51008042792.json (deflated 92%)
#   adding: content/results/X51006414677.json (deflated 92%)
#   adding: content/results/X51007339658.json (deflated 93%)
#   adding: content/results/X51006557202.json (deflated 94%)
#   adding: content/results/X51008030560.json (deflated 93%)
#   adding: content/results/X51007339118.json (deflated 92%)
#   adding: content/results/X51005677329.json (deflated 93%)
#   adding: content/results/X51006335552.json (deflated 94%)
#   adding: content/results/X51005806702.json (deflated 93%)
#   adding: content/results/X51005568880.json (deflated 94%)
#   adding: content/results/X51007419197.json (deflated 93%)
#   adding: content/results/X51008164524.json (deflated 93%)
#   adding: content/results/X51005605335.json (deflated 92%)
#   adding: content/results/X51005719862.json (deflated 92%)
#   adding: content/results/X51006620176.json (deflated 92%)
#   adding: content/results/X51006557188.json (deflated 94%)
#   adding: content/results/X51006619854.json (deflated 92%)
#   adding: content/results/X51005806685.json (deflated 93%)
#   adding: content/results/X51005577192.json (deflated 94%)
#   adding: content/results/X51008099041.json (deflated 93%)
#   adding: content/results/X51007103681.json (deflated 92%)
#   adding: content/results/X51006913028.json (deflated 91%)
#   adding: content/results/X51006557195.json (deflated 94%)
#   adding: content/results/X51006466056.json (deflated 93%)
#   adding: content/results/X51008123451.json (deflated 93%)
#   adding: content/results/X00016469619.json (deflated 93%)
#   adding: content/results/X51005745187.json (deflated 94%)
#   adding: content/results/X51005757346.json (deflated 92%)
#   adding: content/results/X51006913019.json (deflated 92%)
#   adding: content/results/X51005717526.json (deflated 93%)
#   adding: content/results/X51006388044.json (deflated 93%)
#   adding: content/results/X51007339107.json (deflated 92%)
#   adding: content/results/X51005663293.json (deflated 93%)
#   adding: content/results/X51006556823.json (deflated 94%)
#   adding: content/results/X51005745249.json (deflated 93%)
#   adding: content/results/X51005361897.json (deflated 93%)
#   adding: content/results/X51005433494.json (deflated 93%)
#   adding: content/results/X51005433522.json (deflated 93%)
#   adding: content/results/X51006620186.json (deflated 93%)
#   adding: content/results/X51007339106.json (deflated 92%)
#   adding: content/results/X51006389963.json (deflated 94%)
#   adding: content/results/X51007391372.json (deflated 93%)
#   adding: content/results/X51005444037.json (deflated 93%)
#   adding: content/results/X51006387850.json (deflated 93%)
#   adding: content/results/X51006882603.json (deflated 94%)
#   adding: content/results/X51006619342.json (deflated 92%)
#   adding: content/results/X51006619765.json (deflated 93%)
#   adding: content/results/X51007228448.json (deflated 93%)
#   adding: content/results/X51008114284.json (deflated 93%)
#   adding: content/results/X51005719896.json (deflated 93%)
#   adding: content/results/X51006857660.json (deflated 93%)
#   adding: content/results/X51006619563.json (deflated 92%)
